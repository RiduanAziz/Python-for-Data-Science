# %% [markdown]
# # Common Functions/Methods
# - len
# - max
# - min
# - sorted

# %%
s = "Welcome to Python"

# %%
len(s)
# Out:
# 17

# %%
max(s)
# Out:
# 'y'

# %%
min(s)
# Out:
# ' '

# %%
s
# Out:
# 'Welcome to Python'

# %%
sorted(s)
# Out:
# [' ',
#  ' ',
#  'P',
#  'W',
#  'c',
#  'e',
#  'e',
#  'h',
#  'l',
#  'm',
#  'n',
#  'o',
#  'o',
#  'o',
#  't',
#  't',
#  'y']

# %%
sorted(s, reverse=True)
# Out:
# ['y',
#  't',
#  't',
#  'o',
#  'o',
#  'o',
#  'n',
#  'm',
#  'l',
#  'h',
#  'e',
#  'e',
#  'c',
#  'W',
#  'P',
#  ' ',
#  ' ']

# %% [markdown]
# ## Strings Functions/Methods
# - Capitalize
# - Title
# - Upper
# - Lower
# - Swapcase

# %%
s.capitalize()
# Out:
# 'Welcome to python'

# %%
s.title()
# Out:
# 'Welcome To Python'

# %%
s.upper()
# Out:
# 'WELCOME TO PYTHON'

# %%
s.lower()
# Out:
# 'welcome to python'

# %%
s.swapcase()
# Out:
# 'wELCOME TO pYTHON'

# %% [markdown]
# - Count
# - Find
# - Index

# %%
s.count("e")
# Out:
# 2

# %%
s.find("P")
# Out:
# 11

# %%
s.index("P")
# Out:
# 11

# %% [markdown]
# - endswith
# - startswith

# %%
s.endswith("on")
# Out:
# True

# %%
s.startswith("Wel")
# Out:
# True

# %% [markdown]
# - format

# %%
name = "Riduan"
gender = "Male"

s = "My name is {}, and I am a {}"

# %%
s.format(name, gender)
# Out:
# 'My name is Riduan, and I am a Male'

# %%
s = "My name is {1}, and I am a {0}"

# %%
s.format(name, gender)
# Out:
# 'My name is Male, and I am a Riduan'

# %% [markdown]
# ## f-strings

# %%
age = 25
s = f"My name is {name}, and I am a {gender}. I am {age} years old"
print(s)
# Out:
# My name is Riduan, and I am a Male. I am 25 years old

# %% [markdown]
# - isalnum
# - isalpha
# - isdigit
# - isidentifier

# %%
s.isalnum()
# Out:
# False

# %%
s.isalpha()
# Out:
# False

# %%
s = "123"
s.isdigit()
# Out:
# True

# %%
s = "name_age"
s.isidentifier()
# Out:
# True

# %% [markdown]
# - Split
# - Join

# %%
s.split()
# Out:
# ['Welcome', 'to', 'Python']

# %%
s = "My@Name@is@Riduan@Aziz"

# %%
s.split("@")
# Out:
# ['My', 'Name', 'is', 'Riduan', 'Aziz']

# %%
# join
s = ' '
words = ['My', 'name', 'is', 'Riduan']
s.join(words)
# Out:
# 'My name is Riduan'

# %% [markdown]
# - Replace
# - Strip

# %%
s = "My name is Bappy"
s.replace("Bappy", "Riduan")
# Out:
# 'My name is Riduan'

# %%
s = 'My name is Riduan                   '
s.strip()
# Out:
# 'My name is Riduan'
